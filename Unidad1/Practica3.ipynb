# %% [markdown]
# <a href="https://colab.research.google.com/github/PedroRosales123/probabilidad/blob/main/Unidad1/Practica3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **PROBABILIDAD Y ESTADISTICA**
#
# ## GRUPO 2Y
#
# # **UNIDAD 1**
#
# DOCENTE: Jose Gabriel Rodriguez Rivas
#
# Alumno:Pedro Alejandro Rosales Cano
#
# **Practica 3: Tabla de frecuencias y regla de Sturges**

# %%
import random
edades = []
for i in range(100):
  numero_aleatorio = random.randint( 18, 70)
  edades.append (numero_aleatorio)
print(edades)
# Out:
# [25, 64, 42, 37, 44, 46, 19, 36, 67, 53, 53, 36, 25, 24, 36, 60, 65, 23, 70, 58, 47, 47, 57, 47, 44, 62, 27, 21, 27, 50, 41, 66, 35, 28, 58, 69, 25, 55, 22, 56, 31, 35, 54, 22, 34, 29, 29, 50, 45, 43, 37, 33, 25, 46, 40, 53, 43, 48, 28, 22, 53, 63, 39, 32, 47, 47, 27, 47, 24, 57, 63, 22, 50, 18, 66, 70, 55, 29, 65, 56, 20, 69, 26, 43, 46, 66, 32, 64, 57, 31, 43, 32, 45, 51, 22, 33, 31, 52, 18, 52]

# %%
import pandas as pd

# %%
df = pd.DataFrame (edades, columns=['Edad'])
df.head()
# Out:
#    Edad
# 0    25
# 1    64
# 2    42
# 3    37
# 4    44

# %%
tabla_frecuencias = df['Edad'].value_counts().reset_index()
tabla_frecuencias.columns=['Edad','Frecuencia']
tabla_frecuencias = tabla_frecuencias.sort_values(by='Edad')
print("Tabla de distribucion de frecuencias")
tabla_frecuencias
# Out:
# Tabla de distribucion de frecuencias
#     Edad  Frecuencia
# 16    18           2
# 34    19           1
# 44    20           1
# 36    21           1
# 1     22           5
# 31    23           1
# 20    24           2
# 2     25           4
# 45    26           1
# 8     27           3
# 28    28           2
# 12    29           3
# 9     31           3
# 13    32           3
# 18    33           2
# 41    34           1
# 26    35           2
# 5     36           3
# 14    37           2
# 43    39           1
# 40    40           1
# 37    41           1
# 35    42           1
# 4     43           4
# 24    44           2
# 19    45           2
# 6     46           3
# 0     47           6
# 39    48           1
# 11    50           3
# 46    51           1
# 15    52           2
# 3     53           4
# 42    54           1
# 29    55           2
# 27    56           2
# 7     57           3
# 30    58           2
# 32    60           1
# 38    62           1
# 17    63           2
# 23    64           2
# 21    65           2
# 10    66           3
# 33    67           1
# 25    69           2
# 22    70           2

# %%
tabla_frecuencias['Frec Relativa'] = tabla_frecuencias['Frecuencia']/ 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa
# 16    18           2           0.02
# 34    19           1           0.01
# 44    20           1           0.01
# 36    21           1           0.01
# 1     22           5           0.05
# 31    23           1           0.01
# 20    24           2           0.02
# 2     25           4           0.04
# 45    26           1           0.01
# 8     27           3           0.03
# 28    28           2           0.02
# 12    29           3           0.03
# 9     31           3           0.03
# 13    32           3           0.03
# 18    33           2           0.02
# 41    34           1           0.01
# 26    35           2           0.02
# 5     36           3           0.03
# 14    37           2           0.02
# 43    39           1           0.01
# 40    40           1           0.01
# 37    41           1           0.01
# 35    42           1           0.01
# 4     43           4           0.04
# 24    44           2           0.02
# 19    45           2           0.02
# 6     46           3           0.03
# 0     47           6           0.06
# 39    48           1           0.01
# 11    50           3           0.03
# 46    51           1           0.01
# 15    52           2           0.02
# 3     53           4           0.04
# 42    54           1           0.01
# 29    55           2           0.02
# 27    56           2           0.02
# 7     57           3           0.03
# 30    58           2           0.02
# 32    60           1           0.01
# 38    62           1           0.01
# 17    63           2           0.02
# 23    64           2           0.02
# 21    65           2           0.02
# 10    66           3           0.03
# 33    67           1           0.01
# 25    69           2           0.02
# 22    70           2           0.02

# %%
tabla_frecuencias['Frec porcentual'] = tabla_frecuencias['Frecuencia'] / 100 * 100
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual
# 16    18           2           0.02              2.0
# 34    19           1           0.01              1.0
# 44    20           1           0.01              1.0
# 36    21           1           0.01              1.0
# 1     22           5           0.05              5.0
# 31    23           1           0.01              1.0
# 20    24           2           0.02              2.0
# 2     25           4           0.04              4.0
# 45    26           1           0.01              1.0
# 8     27           3           0.03              3.0
# 28    28           2           0.02              2.0
# 12    29           3           0.03              3.0
# 9     31           3           0.03              3.0
# 13    32           3           0.03              3.0
# 18    33           2           0.02              2.0
# 41    34           1           0.01              1.0
# 26    35           2           0.02              2.0
# 5     36           3           0.03              3.0
# 14    37           2           0.02              2.0
# 43    39           1           0.01              1.0
# 40    40           1           0.01              1.0
# 37    41           1           0.01              1.0
# 35    42           1           0.01              1.0
# 4     43           4           0.04              4.0
# 24    44           2           0.02              2.0
# 19    45           2           0.02              2.0
# 6     46           3           0.03              3.0
# 0     47           6           0.06              6.0
# 39    48           1           0.01              1.0
# 11    50           3           0.03              3.0
# 46    51           1           0.01              1.0
# 15    52           2           0.02              2.0
# 3     53           4           0.04              4.0
# 42    54           1           0.01              1.0
# 29    55           2           0.02              2.0
# 27    56           2           0.02              2.0
# 7     57           3           0.03              3.0
# 30    58           2           0.02              2.0
# 32    60           1           0.01              1.0
# 38    62           1           0.01              1.0
# 17    63           2           0.02              2.0
# 23    64           2           0.02              2.0
# 21    65           2           0.02              2.0
# 10    66           3           0.03              3.0
# 33    67           1           0.01              1.0
# 25    69           2           0.02              2.0
# 22    70           2           0.02              2.0

# %%
tabla_frecuencias['Frec acumulada'] = tabla_frecuencias['Frecuencia'].cumsum()
tabla_frecuencias
# Out:
#     Edad  Frecuencia  Frec Relativa  Frec porcentual  Frec acumulada
# 16    18           2           0.02              2.0               2
# 34    19           1           0.01              1.0               3
# 44    20           1           0.01              1.0               4
# 36    21           1           0.01              1.0               5
# 1     22           5           0.05              5.0              10
# 31    23           1           0.01              1.0              11
# 20    24           2           0.02              2.0              13
# 2     25           4           0.04              4.0              17
# 45    26           1           0.01              1.0              18
# 8     27           3           0.03              3.0              21
# 28    28           2           0.02              2.0              23
# 12    29           3           0.03              3.0              26
# 9     31           3           0.03              3.0              29
# 13    32           3           0.03              3.0              32
# 18    33           2           0.02              2.0              34
# 41    34           1           0.01              1.0              35
# 26    35           2           0.02              2.0              37
# 5     36           3           0.03              3.0              40
# 14    37           2           0.02              2.0              42
# 43    39           1           0.01              1.0              43
# 40    40           1           0.01              1.0              44
# 37    41           1           0.01              1.0              45
# 35    42           1           0.01              1.0              46
# 4     43           4           0.04              4.0              50
# 24    44           2           0.02              2.0              52
# 19    45           2           0.02              2.0              54
# 6     46           3           0.03              3.0              57
# 0     47           6           0.06              6.0              63
# 39    48           1           0.01              1.0              64
# 11    50           3           0.03              3.0              67
# 46    51           1           0.01              1.0              68
# 15    52           2           0.02              2.0              70
# 3     53           4           0.04              4.0              74
# 42    54           1           0.01              1.0              75
# 29    55           2           0.02              2.0              77
# 27    56           2           0.02              2.0              79
# 7     57           3           0.03              3.0              82
# 30    58           2           0.02              2.0              84
# 32    60           1           0.01              1.0              85
# 38    62           1           0.01              1.0              86
# 17    63           2           0.02              2.0              88
# 23    64           2           0.02              2.0              90
# 21    65           2           0.02              2.0              92
# 10    66           3           0.03              3.0              95
# 33    67           1           0.01              1.0              96
# 25    69           2           0.02              2.0              98
# 22    70           2           0.02              2.0             100

# %%
import math

# %%
print (edades)
# Out:
# [25, 64, 42, 37, 44, 46, 19, 36, 67, 53, 53, 36, 25, 24, 36, 60, 65, 23, 70, 58, 47, 47, 57, 47, 44, 62, 27, 21, 27, 50, 41, 66, 35, 28, 58, 69, 25, 55, 22, 56, 31, 35, 54, 22, 34, 29, 29, 50, 45, 43, 37, 33, 25, 46, 40, 53, 43, 48, 28, 22, 53, 63, 39, 32, 47, 47, 27, 47, 24, 57, 63, 22, 50, 18, 66, 70, 55, 29, 65, 56, 20, 69, 26, 43, 46, 66, 32, 64, 57, 31, 43, 32, 45, 51, 22, 33, 31, 52, 18, 52]

# %%
df = pd.DataFrame ({'Edad': edades})
df
# Out:
#     Edad
# 0     25
# 1     64
# 2     42
# 3     37
# 4     44
# ..   ...
# 95    33
# 96    31
# 97    52
# 98    18
# 99    52
#
# [100 rows x 1 columns]

# %%
n = len (edades)
K = int( 1 + math.log2(n))
print("Valor de n = ", n, " \nNúmero de intervalos =", K)
# Out:
# Valor de n =  100
# Número de intervalos = 7

# %%
tabla_frecuencia = pd.cut( df['Edad'], bins=K, include_lowest=True).value_counts().reset_index()
tabla_frecuencia.columns = ['Clase', 'Frec']
tabla_frecuencia
# Out:
#               Clase  Frec
# 0  (40.286, 47.714]    19
# 1  (17.947, 25.429]    17
# 2  (25.429, 32.857]    15
# 3    (62.571, 70.0]    14
# 4  (47.714, 55.143]    14
# 5  (32.857, 40.286]    12
# 6  (55.143, 62.571]     9

# %%
tabla_frecuencia = tabla_frecuencia.sort_values (by='Clase')
tabla_frecuencia
# Out:
#               Clase  Frec
# 1  (17.947, 25.429]    17
# 2  (25.429, 32.857]    15
# 5  (32.857, 40.286]    12
# 0  (40.286, 47.714]    19
# 4  (47.714, 55.143]    14
# 6  (55.143, 62.571]     9
# 3    (62.571, 70.0]    14

# %%
tabla_frecuencia['Frec Rel'] = tabla_frecuencia['Frec'] /n
tabla_frecuencia['Frec Porc'] = tabla_frecuencia['Frec'] / n * 100
tabla_frecuencia['Frec Ac'] = tabla_frecuencia['Frec'].cumsum()
tabla_frecuencia['Frec Rel Ac'] = tabla_frecuencia['Frec Rel'].cumsum()
tabla_frecuencia['Frec Porc Ac'] = tabla_frecuencia['Frec Porc'].cumsum()

print(tabla_frecuencia)
# Out:
#               Clase  Frec  Frec Rel  Frec Porc  Frec Ac  Frec Rel Ac  \
# 1  (17.947, 25.429]    17      0.17       17.0       17         0.17
# 2  (25.429, 32.857]    15      0.15       15.0       32         0.32
# 5  (32.857, 40.286]    12      0.12       12.0       44         0.44
# 0  (40.286, 47.714]    19      0.19       19.0       63         0.63
# 4  (47.714, 55.143]    14      0.14       14.0       77         0.77
# 6  (55.143, 62.571]     9      0.09        9.0       86         0.86
# 3    (62.571, 70.0]    14      0.14       14.0      100         1.00
#
#    Frec Porc Ac
# 1          17.0
# 2          32.0
# 5          44.0
# 0          63.0
# 4          77.0
# 6          86.0
# 3         100.0

# %%
import matplotlib.pyplot as plt
plt.hist(edades, alpha = 0.5)
plt.title("Histograma de edades basado en la funcion de matplotlib con valores estandar")
# Out:
# Text(0.5, 1.0, 'Histograma de edades basado en la funcion de matplotlib con valores estandar')

# %%
plt.hist(df['Edad'], bins=K, alpha = 0.5)
plt.title('Histograma de edades basado en la regla de Sturges')
plt.xlabel('Edades')
plt.ylabel('Frecuencia')
# Out:
# Text(0, 0.5, 'Frecuencia')
